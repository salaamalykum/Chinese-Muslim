# %% [markdown]
# # Chinese Muslim RAG Dataset Exploration
#
# This notebook demonstrates how to load and explore the dual-track Parquet datasets from the Hugging Face repository `qurancn/Chinese-Muslim`.

# %%
# !pip install -q pandas pyarrow
import pandas as pd

# %% [markdown]
# ## 1. Load the RAG Chunks Split
# This split is optimized for vector embeddings.

# %%
rag_df = pd.read_parquet('../metadata/rag_chunks.parquet')
print(f"Total RAG chunks: {len(rag_df)}")
rag_df.head(3)
